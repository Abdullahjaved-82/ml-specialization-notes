# %% [markdown]
# # ReLU Activation

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

# %%
#model defination
model = Sequential([
    tf.keras.Input(shape=(2,)),
    Dense(units=25,activation='relu',name='layer_1'),
     Dense(units=15, activation='relu', name='layer2'),
    Dense(units=1, activation='sigmoid', name='layer3'),
   
],name='ReLU_model') #naming model

# %%
model.summary()  #checking the number of parameters
# Out:
# Model: "ReLU_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ layer_1 (Dense)                      │ (None, 25)                  │              75 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer2 (Dense)                       │ (None, 15)                  │             390 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer3 (Dense)                       │ (None, 1)                   │              16 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 481 (1.88 KB)
#  Trainable params: 481 (1.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model._name = 'ReLU_model' #Renaming the model

# %%
def load_coffee_data():
    np.random.seed(2)
    X = np.random.rand(400,2)
    X[:,0] = X[:,0] * (285-150) + 150
    X[:,1] = X[:,1] * 4 + 11.5
    Y = np.zeros(len(X))
    for i in range(len(X)):
        t,d = X[i]
        y = -3/(260-175)*t + 21
        if (t > 175 and t < 260 and d > 12 and d < 15 and d <= y):
            Y[i] = 1
    return X, Y.reshape(-1,1)

X, Y = load_coffee_data()

#normlization
norm_l = tf.keras.layers.Normalization(axis=-1)
norm_l.adapt(X)
Xn = norm_l(X)

#compiling the model
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01)
)

#training 
model.fit(Xn, Y, epochs=10)

X_test = np.array([[200,13.9],[200,17]])
X_testn = norm_l(X_test)

#prediction
predictions = model.predict(X_testn)
print("predictions:\n", predictions)

#threshold
yhat = (predictions >= 0.5).astype(int)
print("decisions:\n", yhat)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1302
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1108
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0975
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0942
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0886
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0884
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0821
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0722
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0603
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# predictions:
#  [[0.69266045]
#  [0.        ]]
# decisions:
#  [[1]
#  [0]]

# %% [markdown]
# ### Summary
# This lab implemented ReLU activation by hand (max(0,z)) and built a 3-layer neural network in TensorFlow — two hidden layers using ReLU and an output layer using sigmoid for binary classification.
