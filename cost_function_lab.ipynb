# %% [markdown]
# # Cost Function for Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Data for house prediction

# %%
x_train = np.array([5.0,8.0,10.0])
y_train = np.array([115.0,190.0,250.0])

# %%
def computecost(x,y,w,b):
    m = x.shape[0]
    cost_sum = 0
    for i in range(m):
        f_wb = w*x[i]+b
        cost = (f_wb-y[i])**2
        cost_sum+=cost
    total_cost = (1/(2*m))*cost_sum
    return total_cost

# %%
w = 200
b = 100
cost = computecost(x_train,y_train,w,b)
print(f"cost as w= {w} and b= {b} is : {cost}")
# Out:
# cost as w= 200 and b= 100 is : 1112137.5

# %%
w_values = np.arange(0, 400, 10)
cost_values = []

for w in w_values:
    cost_values.append(computecost(x_train, y_train, w, b))

plt.plot(w_values, cost_values)
plt.xlabel("w")
plt.ylabel("Cost")
plt.title("Cost vs w")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
